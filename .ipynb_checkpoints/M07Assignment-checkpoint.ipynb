# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron

# %%
data = pd.read_csv('exam_pass_fail_dataset.csv')

# %%
data.iloc[0]
# Out:
# Age                      0.000000
# Gender                   1.000000
# Hours_Studied            0.533333
# Attendance_Percentage    0.615385
# Quiz_Score               0.272727
# Exam_Prep_Days           0.166667
# Stress_Level             0.000000
# Parental_Support         0.000000
# Pass_Fail                1.000000
# Name: 0, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    100 non-null    int64
#  1   Gender                 100 non-null    int64
#  2   Hours_Studied          100 non-null    float64
#  3   Attendance_Percentage  100 non-null    int64
#  4   Quiz_Score             100 non-null    int64
#  5   Exam_Prep_Days         100 non-null    int64
#  6   Stress_Level           100 non-null    int64
#  7   Parental_Support       100 non-null    int64
#  8   Pass_Fail              100 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 7.2 KB

# %%
data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Hours_Studied            0
# Attendance_Percentage    0
# Quiz_Score               0
# Exam_Prep_Days           0
# Stress_Level             0
# Parental_Support         0
# Pass_Fail                0
# dtype: int64

# %%
data.head(5)
# Out:
#    Age  Gender  Hours_Studied  Attendance_Percentage  Quiz_Score  \
# 0   18       1            2.9                     84          62
# 1   20       0            2.8                     99          72
# 2   19       0            3.4                     60          74
# 3   18       0            1.6                     75          84
# 4   18       1            3.2                     98          90
#
#    Exam_Prep_Days  Stress_Level  Parental_Support  Pass_Fail
# 0               2             1                 0          1
# 1               4             5                 0          0
# 2               5             7                 1          0
# 3               5             6                 0          0
# 4               5             1                 1          0

# %%
data.describe()
# Out:
#               Age  Gender  Hours_Studied  Attendance_Percentage  Quiz_Score  \
# count  100.000000  100.00     100.000000             100.000000  100.000000
# mean    19.510000    0.55       2.614000              81.210000   72.140000
# std      1.159023    0.50       1.300351              11.711425   13.014382
# min     18.000000    0.00       0.500000              60.000000   50.000000
# 25%     18.000000    0.00       1.600000              71.000000   61.000000
# 50%     20.000000    1.00       2.500000              83.000000   71.500000
# 75%     21.000000    1.00       3.600000              91.250000   84.250000
# max     21.000000    1.00       5.000000              99.000000   94.000000
#
#        Exam_Prep_Days  Stress_Level  Parental_Support   Pass_Fail
# count      100.000000    100.000000        100.000000  100.000000
# mean         3.820000      4.560000          0.480000    0.520000
# std          1.961138      2.519901          0.502117    0.502117
# min          1.000000      1.000000          0.000000    0.000000
# 25%          2.000000      2.000000          0.000000    0.000000
# 50%          4.000000      5.000000          0.000000    1.000000
# 75%          5.000000      6.000000          1.000000    1.000000
# max          7.000000      9.000000          1.000000    1.000000

# %%
data.mean()
# Out:
# Age                      19.510
# Gender                    0.550
# Hours_Studied             2.614
# Attendance_Percentage    81.210
# Quiz_Score               72.140
# Exam_Prep_Days            3.820
# Stress_Level              4.560
# Parental_Support          0.480
# Pass_Fail                 0.520
# dtype: float64

# %%
correlation = data.corr()
correlation["Pass_Fail"].sort_values(ascending = False)
# Out:
# Pass_Fail                1.000000
# Gender                   0.136795
# Parental_Support         0.121795
# Quiz_Score               0.100040
# Attendance_Percentage    0.087741
# Exam_Prep_Days           0.003693
# Stress_Level            -0.064824
# Age                     -0.113166
# Hours_Studied           -0.158230
# Name: Pass_Fail, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 10))

colormap = sns.color_palette("BrBG", 10)

sns.heatmap(correlation, cmap=colormap, annot=True, fmt=".2f")

ax.set_yticklabels(correlation.columns); #chatGPT help find columns

plt.show()

# %%
def min_max_scale_column(column):
    # scale values between 0 and 1 for each column
    min_value = column.min()
    max_value = column.max()
    return(column - min_value)/(max_value - min_value)

# %%
data = data.apply(min_max_scale_column)

# %%
data.describe()
# Out:
#               Age  Gender  Hours_Studied  Attendance_Percentage  Quiz_Score  \
# count  100.000000  100.00     100.000000             100.000000  100.000000
# mean     0.503333    0.55       0.469778               0.543846    0.503182
# std      0.386341    0.50       0.288967               0.300293    0.295781
# min      0.000000    0.00       0.000000               0.000000    0.000000
# 25%      0.000000    0.00       0.244444               0.282051    0.250000
# 50%      0.666667    1.00       0.444444               0.589744    0.488636
# 75%      1.000000    1.00       0.688889               0.801282    0.778409
# max      1.000000    1.00       1.000000               1.000000    1.000000
#
#        Exam_Prep_Days  Stress_Level  Parental_Support   Pass_Fail
# count      100.000000    100.000000        100.000000  100.000000
# mean         0.470000      0.445000          0.480000    0.520000
# std          0.326856      0.314988          0.502117    0.502117
# min          0.000000      0.000000          0.000000    0.000000
# 25%          0.166667      0.125000          0.000000    0.000000
# 50%          0.500000      0.500000          0.000000    1.000000
# 75%          0.666667      0.625000          1.000000    1.000000
# max          1.000000      1.000000          1.000000    1.000000

# %%
dataShuffled = data.sample(frac=1, random_state = 42)
dataShuffled
# Out:
#          Age  Gender  Hours_Studied  Attendance_Percentage  Quiz_Score  \
# 83  0.666667     0.0       0.133333               0.512821    0.045455
# 53  0.333333     1.0       0.000000               0.820513    0.886364
# 70  0.666667     0.0       0.044444               0.641026    1.000000
# 45  0.000000     0.0       0.133333               0.025641    0.250000
# 44  0.000000     0.0       0.844444               0.384615    0.386364
# ..       ...     ...            ...                    ...         ...
# 60  0.333333     0.0       0.022222               1.000000    0.818182
# 71  0.666667     0.0       0.311111               0.179487    0.068182
# 14  0.333333     1.0       0.488889               0.717949    0.909091
# 92  1.000000     1.0       0.088889               0.435897    0.000000
# 51  0.333333     0.0       0.622222               0.282051    0.136364
#
#     Exam_Prep_Days  Stress_Level  Parental_Support  Pass_Fail
# 83        1.000000         0.250               1.0        1.0
# 53        0.000000         0.625               0.0        1.0
# 70        0.000000         0.125               0.0        1.0
# 45        0.500000         0.625               0.0        0.0
# 44        0.166667         0.125               1.0        1.0
# ..             ...           ...               ...        ...
# 60        0.666667         0.375               0.0        1.0
# 71        0.166667         0.250               1.0        0.0
# 14        0.333333         0.250               1.0        1.0
# 92        0.333333         0.625               1.0        1.0
# 51        0.833333         0.375               0.0        0.0
#
# [100 rows x 9 columns]

# %%
splitIndex = int(0.8*len(dataShuffled))
splitIndex
# Out:
# 80

# %%
trainData = dataShuffled[:splitIndex]
testData = dataShuffled[splitIndex:]

# %%
perceptron = Perceptron()

# %%
featureDataTrain = trainData.iloc[:,:-1] # all but last column for features
featureTargetTrain = trainData.iloc[:,-1] #last column for target

# %%
perceptron.fit(featureDataTrain, featureTargetTrain)
# Out:
# Perceptron()

# %%
#display weightings
for feature, weight in zip(featureDataTrain, perceptron.coef_[0]):
    print(feature, weight)
print("Bias: ", perceptron.intercept_[0])
# Out:
# Age 1.666666666666666
# Gender 1.0
# Hours_Studied -0.37777777777777743
# Attendance_Percentage 0.8205128205128238
# Quiz_Score 1.3181818181818172
# Exam_Prep_Days 2.000000000000001
# Stress_Level -1.125
# Parental_Support 2.0
# Bias:  0.0

# %%
featureDataTest = testData.iloc[:, :-1]
featureTargetTest = testData.iloc[:,-1]

testPredictions = perceptron.predict(featureDataTest)
