# %%
# !pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
music = pd.read_csv('music.csv')

# %%
music
# Out:
#                     Title           Artist  \
# 0                Lollipop        Lil Wayne
# 1            reincarnated   Kendrick Lamar
# 2                Days Off         Lil Baby
# 3                Rockstar       Nickelback
# 4                 Beat It  Michael Jackson
# 5             Annihilate     Metro Booming
# 6             Cozy Forver          Kembe X
# 7                 Warning    Morgan Wallen
# 8  Rock Wit U (Awww Baby)          Ashanti
# 9                Jump Off             Nic.
#
#                                                Album  Year      Genre Duration
# 0                                     Tha Carter III  2008    Hip-Hop     4:59
# 1                                                GNX  2024        Rap     4:35
# 2                                     Perfect Timing  2017        Rap     3:03
# 3                              All the Right Reasons  2005       Rock     4:12
# 4                                           Thriller  1982  Hard Rock     4:18
# ...

# %%
music.head()
# Out:
#           Title           Artist                  Album  Year      Genre  \
# 0      Lollipop        Lil Wayne         Tha Carter III  2008    Hip-Hop
# 1  reincarnated   Kendrick Lamar                    GNX  2024        Rap
# 2      Days Off         Lil Baby         Perfect Timing  2017        Rap
# 3      Rockstar       Nickelback  All the Right Reasons  2005       Rock
# 4       Beat It  Michael Jackson               Thriller  1982  Hard Rock
#
#   Duration
# 0     4:59
# 1     4:35
# 2     3:03
# 3     4:12
# 4     4:18

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     10 non-null     object
#  1   Artist    10 non-null     object
#  2   Album     10 non-null     object
#  3   Year      10 non-null     int64
#  4   Genre     10 non-null     object
#  5   Duration  10 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 612.0+ bytes

# %%
music.to_json('musicJson.json')

# %%
music.to_xml('musicXml.xml')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21436\3910745632.py in ?()
# ----> 1 music.to_xml('musicXml.xml')
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     329                     msg.format(arguments=_format_argument_list(allow_args)),
#     330                     FutureWarning,
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, path_or_buffer, index, root_name, row_name, na_rep, attr_cols, elem_cols, namespaces, prefix, encoding, xml_declaration, pretty_print, parser, stylesheet, compression, storage_options)
#    3610         if parser == "lxml":
# ...

# %%
test = pd.read_json('musicJson.json')
test.head()
# Out:
#           Title           Artist                  Album  Year      Genre  \
# 0      Lollipop        Lil Wayne         Tha Carter III  2008    Hip-Hop
# 1  reincarnated   Kendrick Lamar                    GNX  2024        Rap
# 2      Days Off         Lil Baby         Perfect Timing  2017        Rap
# 3      Rockstar       Nickelback  All the Right Reasons  2005       Rock
# 4       Beat It  Michael Jackson               Thriller  1982  Hard Rock
#
#   Duration
# 0     4:59
# 1     4:35
# 2     3:03
# 3     4:12
# 4     4:18
